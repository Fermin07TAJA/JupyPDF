# %% [markdown]
# <div style="margin-top: 2in;"></div>
#
# <div align="center" style="font-size: large;">Joaquin Paz</div>
# <div align="center" style="font-size: large;"> Class / Assig </div>
# <div align="center" style="font-size: large;"> DATE </div>
# <br>
# <hr>
# <br>
#
# >All functions to compute and format imaginary numbers or to graph with "fgmk2" are from the python packages "chyk" or "fgmkr." This is still my own work as I update and maintain both packages on a weekly basis for my classes. I am not "outsourcing" my work to a black box as I created those functions.
#
# All answers are to three sig figs. The density of the air is 1.21 $\frac{kg}{m^3}$  and gravity is  9.81 $\frac{m}{s}^2$ for all of these problems.

# %%
from chyk import *
handcalcs.set_option("param_columns", 2)
from math import degrees as r2d
from math import radians as d2r
rho = 1.21  # $\frac{kg}{m^3}$, air density
g = 9.81  # $\frac{m}{s^2}$
